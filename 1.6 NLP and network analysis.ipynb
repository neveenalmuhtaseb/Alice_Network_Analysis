# %% [markdown]
# # Import libraries

# %%
import pandas as pd 
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
NER = spacy.load("en_core_web_sm")

# %% [markdown]
# # Creating an NER Object

# %%
# Load the book

with open('alice_article_wiki.txt', 'r', errors='ignore') as file: 
   data = file.read().replace( '\n', ' ')

book = NER(data)

# %%
# Visualize identified entities

displacy.render(book[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">српскохрватскиSuomiSvenskaதமிழ்TaqbaylitTayalไทยTürkçeУкраїнськаاردوTiếng ViệtWalon文言Winaray吴语粵語中文  Edit links            ArticleTalk
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
#                   ReadEditView history
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tools      Tools
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  move to sidebar hide    		Actions 	   ReadEditView history      		General 	   What links hereRelated changesUpload filePermanent linkPage informationCite this pageGet shortened
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     URLDownload
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  QR code      		Print/export
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Download
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PDFPrintable
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  version      		In other projects
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikimedia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  CommonsWikiquoteWikisourceWikidata item                      Appearance move to sidebar hide           From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikipedia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the free encyclopedia
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1865
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  children's novel by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lewis Carroll &quot;Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot; redirects here. For other uses, see
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (disambiguation).
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice's Adventures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  First edition cover (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1865)AuthorLewis CarrollIllustratorJohn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  TennielLanguageEnglishGenrePortal fantasyLiterary nonsensePublisherMacmillanPublication dateNovember 1865Publication placeUnited
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     KingdomFollowed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  byThrough
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Looking-Glass
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TextAlice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adventures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikisource Alice's Adventures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (also known as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; mar

# %%
# import the countries data set 
countries_df=pd.read_csv(r'/Users/yasersouri/Desktop/data analysis/specialization 1/Alice_Network_Analysis/characters_df.csv',index_col=0)

# %%
displacy.render(book, options = {'ents': ['GPE']}, style = 'ent', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">    Alice's Adventures in Wonderland - Wikipedia                                    Jump to content        Main menu      Main menu move to sidebar hide    		Navigation 	   Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us      		Contribute 	   HelpLearn to editCommunity portalRecent changesUpload fileSpecial pages                    Search            Search                       Appearance                 Donate  Create account  Log in         Personal tools      Donate Create account Log in      		Pages for logged out editors learn more    ContributionsTalk                             Contents move to sidebar hide     (Top)      1 Background     Toggle Background subsection      1.1 &quot;All in the golden afternoon...&quot;         1.2 Manuscript: Alice's Adventures Under Ground           2 Plot         3 Characters     Toggle Characters subsection      3.1 Character allusions           4 Poems and songs         5 Writing style and themes     Toggle Writing style and themes subsection      5.1 Symbolism         5.2 Language         5.3 Mathematics         5.4 Eating and devouring         5.5 Nonsense         5.6 Rules and games           6 Illustrations         7 Publication history     Toggle Publication history subsection      7.1 Publication timeline           8 Reception         9 Adaptations and influence     Toggle Adaptations and influence subsection      9.1 Live performance           10 Commemoration         11 See also         12 References     Toggle References subsection      12.1 Works cited           13 External links     Toggle External links subsection      13.1 Text         13.2 Audio         13.3 Archival materials                     Toggle the table of contents        Alice's Adventures in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#     97 languages     AfrikaansAlemannischÆngliscالعربيةԱրեւմտահայերէնAsturianuAzərbaycancaবাংলা閩南語 / Bân-lâm-gúБашҡортсаБеларускаяБеларуская (тарашкевіца)БългарскиBosanskiBrezhonegCatalàČeštinaCymraegDanskDeutschEestiΕλληνικάEspañolEsperantoEuskaraفارسیFrançaisFryskGaeilgeGalegoગુજરાતી𐌲𐌿𐍄𐌹𐍃𐌺한국어Հայերենहिन्दीHrvatskiIdoBahasa IndonesiaInterlinguaÍslenskaItalianoעבריתಕನ್ನಡქართულიҚазақшаKurdîКыргызчаLatinaLatviešuLietuviųLingua Franca NovaMagyarМакедонскиമലയാളംमराठीBahasa Melayuꯃꯤꯇꯩ ꯂꯣꯟမြန်မာဘာသာNederlands日本語Norsk bokmålNorsk nynorskOccitanOʻzbekcha / ўзбекчаਪੰਜਾਬੀPangcahپنجابیPolskiPortuguêsRomânăРусскийSakizayaScotsSeediqShqipSimple EnglishSlovenčinaŚlůnskiکوردیСрпски / srpskiSrpskohrvatski / српскохрватскиSuomiSvenskaதமிழ்TaqbaylitTayalไทยTürkçeУкраїнськаاردوTiếng ViệtWalon文言Winaray吴语粵語中文  Edit links            ArticleTalk      English                  ReadEditView history        Tools      Tools move to sidebar hide    		Actions 	   ReadEditView history      		General 	   What links hereRelated changesUpload filePermanent linkPage informationCite this pageGet shortened URLDownload QR code      		Print/export
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Download
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as PDFPrintable version      		In other projects 	   Wikimedia CommonsWikiquoteWikisourceWikidata item                      Appearance move to sidebar hide           From Wikipedia, the free encyclopedia   1865 children's novel by Lewis Carroll &quot;Alice in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot; redirects here. For other uses, see Alice in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (disambiguation).   Alice's Adventures in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  First edition cover (1865)AuthorLewis CarrollIllustratorJohn TennielLanguageEnglishGenrePortal fantasyLiterary nonsensePublisherMacmillanPublication dateNovember 1865Publication placeUnited KingdomFollowed byThrough the Looking-Glass TextAlice's Adventures in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  at Wikisource Alice's Adventures in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (also known as  Alice in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ) is an 1865 English children's novel by Lewis Carroll, a mathematics don at the University of Oxford. It details the story of a girl named Alice who falls through a rabbit hole into a fantasy world of anthropomorphic creatures. It is seen as an example of the literary nonsense genre. The artist Sir John Tenniel provided 42 wood-engraved illustrations for the book.  It received positive reviews upon release and is now one of the best-known works of Victorian literature; its narrative, structure, characters and imagery have had a widespread influence on popular culture and literature, especially in the fantasy genre.[1][2] It is credited as helping end an era of didacticism in children's literature, inaugurating an era in which writing for children aimed to &quot;delight or entertain&quot;.[3] The tale plays with logic, giving the story lasting popularity with adults as well as with children.[4] The titular character Alice shares her name with Alice Liddell, a girl Carroll knew—scholars disagree about the extent to which the character was based upon her.[5][6] The book has never been out of print and has been translated into 174 languages. Its legacy includes adaptations to screen, radio, visual art, ballet, opera, and musical theatre, as well as theme parks, board games and video games.[7] Carroll published a sequel in 1871 entitled Through the Looking-Glass and a shortened version for young children, The Nursery &quot;Alice&quot;, in 1890.   Background[edit] &quot;All in the golden afternoon...&quot;[edit] Alice's Adventures in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was conceived on 4 July 1862, when Lewis Carr

# %% [markdown]
# ## Splitting Sentence Entities

# %%
df_sentences = []

# Loop through sentences, get entity list for each sentence
for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})

df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (    , Alice, 's, Adventures, in, Wonderland, ...
# 1  (Edit, links,            , ArticleTalk,      ,...
# 2  (informationCite, this, pageGet, shortened, UR...
# 3  (Wikimedia, CommonsWikiquoteWikisourceWikidata...
# 4  (For, other, uses, ,, see, Alice, in, Wonderla...
# 5  (Alice, 's, Adventures, in, Wonderland, First,...
# 6  (It, details, the, story, of, a, girl, named, ...
# 7  (It, is, seen, as, an, example, of, the, liter...
# 8  (The, artist, Sir, John, Tenniel, provided, 42...
# 9  (It, received, positive, reviews, upon, releas...
#
#                                             entities
# 0  [Wonderland - Wikipedia                       ...
# 1                        [English, Tools      Tools]
# 2              [URLDownload, Download, PDFPrintable]
# 3  [Wikimedia, Wikipedia, 1865, Lewis Carroll "Al...
# 4                                [Alice, Wonderland]
# 5  [Alice's Adventures, Wonderland, 1865)AuthorLe...
# 6                                            [Alice]
# 7                                                 []
# 8                                 [John Tenniel, 42]
# 9                                        [Victorian]

# %% [markdown]
# ## Filtering Data Using the Main Countries

# %%
# import the characters data set as a pandas dataframe
character_df=pd.read_csv('/Users/yasersouri/Desktop/data analysis/specialization 1/Alice_Network_Analysis/characters_df.csv',index_col=0)

# %%
character_df['character_alias'] = character_df['character'].apply(lambda x: x.rsplit(' ',1)[-1])

# %%
# Function to filter out entities not of interest
def filter_entity(ent_list, character_df):
    return [ent for ent in ent_list if ent in list(character_df['character_alias'])]

# %%
# pass the sentence entities and the characters dataframe into a filter, which will return only the entities of interest:
df_sentences['character_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, character_df))

# %%
# Filter out sentences that don’t have any country entities

df_sentences_filtered = df_sentences[df_sentences['character_entities'].map(len) > 0]

df_sentences_filtered.tail(10)
# Out:
#                                               sentence  \
# 791  (Alice, and, the, Land, that, Wonders, (, 2020...
# 792  (Alice, in, Wonderland, or, What, 's, a, Nice,...
# 793  (Alice, in, Wonderland, (, 1966, ), Alice, Thr...
# 796  (Alice, through, the, Looking, Glass, (, 1998, ))
# 797  (Alice, in, Wonderland, (, 1999, ), Alice, (, ...
# 798  (Once, Upon, a, Time, in, Wonderland, (, 2013,...
# 800                (Alice, in, Wonderland, (, 2010, ))
# 801  (Almost, Alice, (, 2010, ), ", Alice, ", ", Fo...
# 802  (", Just, Like, Fire, ", ", Alice, ", (, 2020,...
# 804  (Alice, no, Paint, Adventure, (, 1995, ), Alic...
#
#                                               entities  \
# 791       [Alice, 2020, Alice, 2021, Wonderland, 1962]
# 792                          [Alice, Wonderland, 1966]
# 793     [Alice, Wonderland, 1966, Alice Through, 1983]
# 796                   [Alice, the Looking Glass, 1998]
# 797             [Alice, Wonderland, 1999, Alice, 2009]
# 798  [Wonderland, 2013, Alice, 2022, Artwork Alice,...
# 800                          [Alice, Wonderland, 2010]
# 801  [Alice, 2010, Alice, Follow Me Down, Tea Party...
# 802  [Just Like Fire, Alice, 2020, the Looking Glas...
# 804  [Alice no Paint Adventure, 1995, Alice, Wonder...
#
#                character_entities
# 791                [Alice, Alice]
# 792                       [Alice]
# 793                       [Alice]
# 796                       [Alice]
# 797                [Alice, Alice]
# 798                       [Alice]
# 800                       [Alice]
# 801                [Alice, Alice]
# 802                [Alice, Alice]
# 804  [Alice, Alice, Alice, Alice]

# %%
# Filter out sentences that don’t have any character entities

df_sentences_filtered = df_sentences[df_sentences['character_entities'].map(len) > 0]

df_sentences_filtered.tail(10)
# Out:
#                                               sentence  \
# 791  (Alice, and, the, Land, that, Wonders, (, 2020...
# 792  (Alice, in, Wonderland, or, What, 's, a, Nice,...
# 793  (Alice, in, Wonderland, (, 1966, ), Alice, Thr...
# 796  (Alice, through, the, Looking, Glass, (, 1998, ))
# 797  (Alice, in, Wonderland, (, 1999, ), Alice, (, ...
# 798  (Once, Upon, a, Time, in, Wonderland, (, 2013,...
# 800                (Alice, in, Wonderland, (, 2010, ))
# 801  (Almost, Alice, (, 2010, ), ", Alice, ", ", Fo...
# 802  (", Just, Like, Fire, ", ", Alice, ", (, 2020,...
# 804  (Alice, no, Paint, Adventure, (, 1995, ), Alic...
#
#                                               entities  \
# 791       [Alice, 2020, Alice, 2021, Wonderland, 1962]
# 792                          [Alice, Wonderland, 1966]
# 793     [Alice, Wonderland, 1966, Alice Through, 1983]
# 796                   [Alice, the Looking Glass, 1998]
# 797             [Alice, Wonderland, 1999, Alice, 2009]
# 798  [Wonderland, 2013, Alice, 2022, Artwork Alice,...
# 800                          [Alice, Wonderland, 2010]
# 801  [Alice, 2010, Alice, Follow Me Down, Tea Party...
# 802  [Just Like Fire, Alice, 2020, the Looking Glas...
# 804  [Alice no Paint Adventure, 1995, Alice, Wonder...
#
#                character_entities
# 791                [Alice, Alice]
# 792                       [Alice]
# 793                       [Alice]
# 796                       [Alice]
# 797                [Alice, Alice]
# 798                       [Alice]
# 800                       [Alice]
# 801                [Alice, Alice]
# 802                [Alice, Alice]
# 804  [Alice, Alice, Alice, Alice]

# %% [markdown]
# ## Creating Relationships

# %%
# Defining relationships

# window size = 5 : this defines how many sentences will be looked at simultaneously
relationships = []  # create an empty list

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i + 5, df_sentences_filtered.index[-1])
    characters_list = sum(df_sentences_filtered.loc[i:end_i].character_entities, [])

    # Remove duplicated characters that are next to each other
    char_unique = [
        characters_list[j] for j in range(len(characters_list))
        if (j == 0) or characters_list[j] != characters_list[j - 1]
    ]

    if len(char_unique) > 1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationships_df = pd.DataFrame(relationships)

relationships_df
# Out:
#           source       target
# 0          Alice  Caterpillar
# 1          Alice  Caterpillar
# 2    Caterpillar        Alice
# 3    Caterpillar        Alice
# 4          Alice  Caterpillar
# ..           ...          ...
# 142        Alice       Hatter
# 143       Hatter        Alice
# 144        Alice       Hatter
# 145       Hatter        Alice
# 146       Hatter        Alice
#
# [147 rows x 2 columns]

# %%
# sorting the values in the dataframe first, then use the groupby() function to get all the different frequencies of the source:
# Sort the cases with a- >b and b- >a
relationships_df = pd.DataFrame(np.sort(relationships_df.values, axis = 1), columns = relationships_df.columns)
relationships_df.head(5)
# Out:
#   source       target
# 0  Alice  Caterpillar
# 1  Alice  Caterpillar
# 2  Alice  Caterpillar
# 3  Alice  Caterpillar
# 4  Alice  Caterpillar

# %%
relationships_df["value"] = 1
relationships_df = relationships_df.groupby(["source","target"], sort=False, as_index=False).sum()

relationships_df.head(10)
# Out:
#      source       target  value
# 0     Alice  Caterpillar     18
# 1     Alice      Duchess     24
# 2     Alice       Hatter     26
# 3  Dormouse       Hatter     17
# 4   Duchess      Gryphon      5
# 5     Alice      Gryphon     17
# 6      Duck         Lory      6
# 7     Alice         Lory      4
# 8     Alice        Mouse      7
# 9     Alice         Dodo     12

# %%
relationships_df.to_csv(r'/Users/yasersouri/Desktop/data analysis/specialization 1/Alice_Network_Analysis//relationships_df.csv')
