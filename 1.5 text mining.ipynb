# %% [markdown]
# # Import libraries

# %%
from textblob import TextBlob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from collections import Counter
sns.set()
import nltk
nltk.download('punkt')
from collections import Counter

# Download necessary NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yasersouri/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/yasersouri/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/yasersouri/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/yasersouri/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yasersouri/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/yasersouri/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/yasersouri/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
print(nltk.__version__)
# Out:
# 3.8.1

# %%
# Set up Seaborn style
sns.set()

# %% [markdown]
# # Text mining

# %%
# Import txt file

with open('alice_article_wiki.txt', 'r', errors='ignore') as file: 
   data = file.read().replace( '\n', ' ')

# %%
import nltk
import sys

print("NLTK version:", nltk.__version__)
print("Python version:", sys.version)
# Out:
# NLTK version: 3.8.1
# Python version: 3.13.2 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 12:55:35) [Clang 14.0.6 ]

# %%
import nltk
nltk.download('punkt', download_dir='/Users/yasersouri/nltk_data')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/yasersouri/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.data.path.append('/Users/yasersouri/nltk_data')

# %%
from nltk.tokenize import sent_tokenize

# %%
# Sentence tokenization

from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)
print(tokenized_sent)
# Out:
# ["    Alice in Wonderland (franchise) - Wikipedia                                     Jump to content        Main menu      Main menu move to sidebar hide    \t\tNavigation \t   Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us      \t\tContribute \t   HelpLearn to editCommunity portalRecent changesUpload fileSpecial pages                    Search            Search                       Appearance                 Donate  Create account  Log in         Personal tools      Donate Create account Log in      \t\tPages for logged out editors learn more    ContributionsTalk                             Contents move to sidebar hide     (Top)      1 Films     Toggle Films subsection      1.1 Animated films       1.1.1 Alice in Wonderland           1.2 Live-action films       1.2.1 Alice in Wonderland         1.2.2 Alice Through the Looking Glass             2 TV series     Toggle TV series subsection      2.1 Adventures in Wonderland         2.2 Once Upon a Time in Wonderland         2.3 Alice's Wonderland Bakery           3 Video games     Toggle Video games subsection      3.1 Alice in Wonderland (2000)         3.2 Kingdom Hearts series         3.3 Alice in Wonderland (2010)         3.4 Disney Infinity series         3.5 Disney Magic Kingdoms           4 Theme park attractions and rides     Toggle Theme park attractions and rides subsection      4.1 Alice in Wonderland Maze         4.2 Alice's Curious Labyrinth         4.3 Mad Tea Party         4.4 Alice in Wonderland (ride)         4.5 Mad T Party         4.6 It's a Small World           5 Stage version     Toggle Stage version subsection      5.1 Alice in Wonderland Jr.           6 Music     Toggle Music subsection      6.1 Alice in Wonderland soundtrack         6.2 Almost Alice           7 References                   Toggle the table of contents        Alice in Wonderland (franchise)    2 languages     БългарскиEspañol  Edit links            ArticleTalk      English                  ReadEditView history        Tools      Tools move to sidebar hide    \t\tActions \t   ReadEditView history      \t\tGeneral \t   What links hereRelated changesUpload filePermanent linkPage informationCite this pageGet shortened URLDownload QR code      \t\tPrint/export \t   Download as PDFPrintable version      \t\tIn other projects \t   Wikidata item                      Appearance move to sidebar hide           From Wikipedia, the free encyclopedia   Disney media franchise based on the Alice books by Lewis Carroll See also: Portrayals of Alice in Wonderland §\xa0Disney Alice in WonderlandAbove: A logo used to represent the 1951 animated filmBelow: Logo used for the 2010 live-action filmCreated byWalt DisneyOriginal workAlice in Wonderland (1951)OwnerThe Walt Disney CompanyYears1951-2024Based onAlice's Adventures in Wonderland and Through the Looking-Glassby Lewis CarrollFilms and televisionFilm(s) Alice in Wonderland (1951; animated) Alice in Wonderland (2010; live-action) Alice Through the Looking Glass (2016) Television series Adventures in Wonderland (1992–1995) Once Upon a Time in Wonderland (2013–2014)** Alice's Wonderland Bakery (2022–2024) Theatrical presentationsPlay(s)Alice in Wonderland Jr.GamesVideo game(s) Alice in Wonderland (2000) Alice in Wonderland (2010) Disney Infinity 3.0 (2015)* AudioSoundtrack(s) Alice in Wonderland (1951) Alice in Wonderland: An Original Walt Disney Records Soundtrack (2010) Alice Through the Looking Glass: Original Motion Picture Soundtrack (2016) Original musicAlmost Alice (2010)MiscellaneousTheme park attraction(s) Mad Tea Party (1955–present) Alice in Wonderland (1958–present) Alice's Curious Labyrinth (1992–present) Mad T Party (2012–2016)  * Work where this franchise's characters or settings appeared as part of a crossover.", '** Spin-off of TV series Once Upon a Time (2011–2018)  Alice in Wonderland, or simply Alice, is a Disney media franchise, commencing in 1951 with the theatrical release of the animated film Alice in Wonderland ...

# %%
# Word tokenization

from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)
print(tokenized_word)
# Out:
# ['Alice', 'in', 'Wonderland', '(', 'franchise', ')', '-', 'Wikipedia', 'Jump', 'to', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'to', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'to', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSpecial', 'pages', 'Search', 'Search', 'Appearance', 'Donate', 'Create', 'account', 'Log', 'in', 'Personal', 'tools', 'Donate', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'ContributionsTalk', 'Contents', 'move', 'to', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Films', 'Toggle', 'Films', 'subsection', '1.1', 'Animated', 'films', '1.1.1', 'Alice', 'in', 'Wonderland', '1.2', 'Live-action', 'films', '1.2.1', 'Alice', 'in', 'Wonderland', '1.2.2', 'Alice', 'Through', 'the', 'Looking', 'Glass', '2', 'TV', 'series', 'Toggle', 'TV', 'series', 'subsection', '2.1', 'Adventures', 'in', 'Wonderland', '2.2', 'Once', 'Upon', 'a', 'Time', 'in', 'Wonderland', '2.3', 'Alice', "'s", 'Wonderland', 'Bakery', '3', 'Video', 'games', 'Toggle', 'Video', 'games', 'subsection', '3.1', 'Alice', 'in', 'Wonderland', '(', '2000', ')', '3.2', 'Kingdom', 'Hearts', 'series', '3.3', 'Alice', 'in', 'Wonderland', '(', '2010', ')', '3.4', 'Disney', 'Infinity', 'series', '3.5', 'Disney', 'Magic', 'Kingdoms', '4', 'Theme', 'park', 'attractions', 'and', 'rides', 'Toggle', 'Theme', 'park', 'attractions', 'and', 'rides', 'subsection', '4.1', 'Alice', 'in', 'Wonderland', 'Maze', '4.2', 'Alice', "'s", 'Curious', 'Labyrinth', '4.3', 'Mad', 'Tea', 'Party', '4.4', 'Alice', 'in', 'Wonderland', '(', 'ride', ')', '4.5', 'Mad', 'T', 'Party', '4.6', 'It', "'s", 'a', 'Small', 'World', '5', 'Stage', 'version', 'Toggle', 'Stage', 'version', 'subsection', '5.1', 'Alice', 'in', 'Wonderland', 'Jr.', '6', 'Music', 'Toggle', 'Music', 'subsection', '6.1', 'Alice', 'in', 'Wonderland', 'soundtrack', '6.2', 'Almost', 'Alice', '7', 'References', 'Toggle', 'the', 'table', 'of', 'contents', 'Alice', 'in', 'Wonderland', '(', 'franchise', ')', '2', 'languages', 'БългарскиEspañol', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'to', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'filePermanent', 'linkPage', 'informationCite', 'this', 'pageGet', 'shortened', 'URLDownload', 'QR', 'code', 'Print/export', 'Download', 'as', 'PDFPrintable', 'version', 'In', 'other', 'projects', 'Wikidata', 'item', 'Appearance', 'move', 'to', 'sidebar', 'hide', 'From', 'Wikipedia', ',', 'the', 'free', 'encyclopedia', 'Disney', 'media', 'franchise', 'based', 'on', 'the', 'Alice', 'books', 'by', 'Lewis', 'Carroll', 'See', 'also', ':', 'Portrayals', 'of', 'Alice', 'in', 'Wonderland', '§', 'Disney', 'Alice', 'in', 'WonderlandAbove', ':', 'A', 'logo', 'used', 'to', 'represent', 'the', '1951', 'animated', 'filmBelow', ':', 'Logo', 'used', 'for', 'the', '2010', 'live-action', 'filmCreated', 'byWalt', 'DisneyOriginal', 'workAlice', 'in', 'Wonderland', '(', '1951', ')', 'OwnerThe', 'Walt', 'Disney', 'CompanyYears1951-2024Based', 'onAlice', "'s", 'Adventures', 'in', 'Wonderland', 'and', 'Through', 'the', 'Looking-Glassby', 'Lewis', 'CarrollFilms', 'and', 'televisionFilm', '(', 's', ')', 'Alice', 'in', 'Wonderland', '(', '1951', ';', 'animated', ')', 'Alice', 'in', 'Wonderland', '(', '2010', ';', 'live-action', ')', 'Alice', 'Through', 'the', 'Looking', 'Glass', '(', '2016', ')', 'Television', 'series', 'Adventures', 'in', 'Wonderland', '(', '1992–1995', ')', 'Once', 'Upon', 'a', 'Time', 'in', 'Wonderland', '(', '2013–2014', ')', '*', '*', 'Alice', "'s", 'Wonderland', 'Bakery', '(', '2022–2024', ')', 'Theatrical', 'presentationsPlay', '(', 's', ')', 'Alice', 'in', 'Wonderland', 'Jr.GamesVideo', 'game', '(', 's', ')', 'Alice', 'in', 'Wonderland', '(', '2000', ')', 'Alice', 'in', 'Wonderland', '(', '2010', ')', 'Disney' ...

# %%
from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 1516 samples and 4961 outcomes>

# %%
dist_words.most_common(10)
# Out:
# [('(', 238),
#  (')', 238),
#  ('Alice', 168),
#  ('in', 164),
#  ('the', 159),
#  ('Wonderland', 124),
#  (',', 121),
#  ('The', 83),
#  ('.', 75),
#  ('of', 74)]

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words.plot(10, cumulative=False)
plt.show()

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

filtered_words = []  # creates an empty list
for word in tokenized_word:
    if word not in stop_words:
        filtered_words.append(word)

# %%
from nltk import FreqDist  # make sure this is included

# Create a new FreqDist for filtered_words
Dist_words_filter = FreqDist(filtered_words)
print(Dist_words_filter)
# Out:
# <FreqDist with 1468 samples and 4186 outcomes>

# %%
# Frequency Distribution Plot
plt.figure(figsize=(8, 3))
Dist_words_filter.plot(10, cumulative=False)  
plt.show()

# %%
# Substitute all punctuation marks with a space

sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                        " ",        # Replace all non-letters with spaces
                        str(filtered_words))

# %%
# Word tokenization
Tokenized_word_2 = word_tokenize(sans_punc)
print(Tokenized_word_2)
# Out:
# ['Alice', 'Wonderland', 'franchise', 'Wikipedia', 'Jump', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSpecial', 'pages', 'Search', 'Search', 'Appearance', 'Donate', 'Create', 'account', 'Log', 'Personal', 'tools', 'Donate', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'ContributionsTalk', 'Contents', 'move', 'sidebar', 'hide', 'Top', 'Films', 'Toggle', 'Films', 'subsection', 'Animated', 'films', 'Alice', 'Wonderland', 'Live', 'action', 'films', 'Alice', 'Wonderland', 'Alice', 'Through', 'Looking', 'Glass', 'TV', 'series', 'Toggle', 'TV', 'series', 'subsection', 'Adventures', 'Wonderland', 'Once', 'Upon', 'Time', 'Wonderland', 'Alice', 's', 'Wonderland', 'Bakery', 'Video', 'games', 'Toggle', 'Video', 'games', 'subsection', 'Alice', 'Wonderland', 'Kingdom', 'Hearts', 'series', 'Alice', 'Wonderland', 'Disney', 'Infinity', 'series', 'Disney', 'Magic', 'Kingdoms', 'Theme', 'park', 'attractions', 'rides', 'Toggle', 'Theme', 'park', 'attractions', 'rides', 'subsection', 'Alice', 'Wonderland', 'Maze', 'Alice', 's', 'Curious', 'Labyrinth', 'Mad', 'Tea', 'Party', 'Alice', 'Wonderland', 'ride', 'Mad', 'T', 'Party', 'It', 's', 'Small', 'World', 'Stage', 'version', 'Toggle', 'Stage', 'version', 'subsection', 'Alice', 'Wonderland', 'Jr', 'Music', 'Toggle', 'Music', 'subsection', 'Alice', 'Wonderland', 'soundtrack', 'Almost', 'Alice', 'References', 'Toggle', 'table', 'contents', 'Alice', 'Wonderland', 'franchise', 'languages', 'Espa', 'ol', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'filePermanent', 'linkPage', 'informationCite', 'pageGet', 'shortened', 'URLDownload', 'QR', 'code', 'Print', 'export', 'Download', 'PDFPrintable', 'version', 'In', 'projects', 'Wikidata', 'item', 'Appearance', 'move', 'sidebar', 'hide', 'From', 'Wikipedia', 'free', 'encyclopedia', 'Disney', 'media', 'franchise', 'based', 'Alice', 'books', 'Lewis', 'Carroll', 'See', 'also', 'Portrayals', 'Alice', 'Wonderland', 'Disney', 'Alice', 'WonderlandAbove', 'A', 'logo', 'used', 'represent', 'animated', 'filmBelow', 'Logo', 'used', 'live', 'action', 'filmCreated', 'byWalt', 'DisneyOriginal', 'workAlice', 'Wonderland', 'OwnerThe', 'Walt', 'Disney', 'CompanyYears', 'Based', 'onAlice', 's', 'Adventures', 'Wonderland', 'Through', 'Looking', 'Glassby', 'Lewis', 'CarrollFilms', 'televisionFilm', 'Alice', 'Wonderland', 'animated', 'Alice', 'Wonderland', 'live', 'action', 'Alice', 'Through', 'Looking', 'Glass', 'Television', 'series', 'Adventures', 'Wonderland', 'Once', 'Upon', 'Time', 'Wonderland', 'Alice', 's', 'Wonderland', 'Bakery', 'Theatrical', 'presentationsPlay', 'Alice', 'Wonderland', 'Jr', 'GamesVideo', 'game', 'Alice', 'Wonderland', 'Alice', 'Wonderland', 'Disney', 'Infinity', 'AudioSoundtrack', 'Alice', 'Wonderland', 'Alice', 'Wonderland', 'An', 'Original', 'Walt', 'Disney', 'Records', 'Soundtrack', 'Alice', 'Through', 'Looking', 'Glass', 'Original', 'Motion', 'Picture', 'Soundtrack', 'Original', 'musicAlmost', 'Alice', 'MiscellaneousTheme', 'park', 'attraction', 'Mad', 'Tea', 'Party', 'present', 'Alice', 'Wonderland', 'present', 'Alice', 's', 'Curious', 'Labyrinth', 'present', 'Mad', 'T', 'Party', 'Work', 'franchise', 's', 'characters', 'settings', 'appeared', 'part', 'crossover', 'Spin', 'off', 'TV', 'series', 'Once', 'Upon', 'Time', 'Alice', 'Wonderland', 'simply', 'Alice', 'Disney', 'media', 'franchise', 'commencing', 'theatrical', 'release', 'animated', 'film', 'Alice', 'Wonderland', 'The', 'film', 'adaptation', 'books', 'Lewis', 'Carroll', 'novel', 'Alice', 's', 'Adventures', 'Wonderland', 'sequel', 'Through', 'Looking', 'Glass', 'featured', 'character', 'Alice', 'A',  ...

# %%
# Create a new FreqDist

dist_words_filter_2 = FreqDist(Tokenized_word_2)

# %%
# Frequency Distribution Plot
plt.figure(figsize=(8, 3))
dist_words_filter_2.plot(10, cumulative=False)  
plt.show()

# %%
new_stopwords = ["And", "Then", 'n', 't', 's', 'The']

filtered = []
for word in Tokenized_word_2:
     if word not in new_stopwords:
        filtered.append(word)

# %%
# %%time
text = TextBlob(str(filtered))
# Out:
# CPU times: user 1.39 ms, sys: 44 μs, total: 1.43 ms
# Wall time: 697 μs

# %%
tags_list = text.tags

# %%
tags_list
# Out:
# [('[', 'JJ'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Wikipedia", 'NNP'),
#  ("'", 'POS'),
#  ("'Jump", 'NNP'),
#  ("'", 'POS'),
#  ("'content", 'NNP'),
#  ("'", 'POS'),
#  ("'menu", 'NNP'),
#  ("'", 'POS'),
#  ("'menu", 'NNP'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Navigation", 'NN'),
#  ("'pageContentsCurrent", 'NNP'),
#  ("'", 'POS'),
#  ("'eventsRandom", 'NNP'),
#  ("'", 'POS'),
#  ("'articleAbout", 'IN'),
#  ("'WikipediaContact", 'NNP'),
#  ("'", 'POS'),
#  ("'us", 'NNP'),
#  ("'", 'POS'),
#  ("'HelpLearn", 'NNP'),
#  ("'", 'POS'),
#  ("'editCommunity", 'NNP'),
#  ("'", 'POS'),
#  ("'portalRecent", 'NNP'),
#  ("'", 'POS'),
#  ("'fileSpecial", 'NNP'),
#  ("'", 'POS'),
#  ("'pages", 'NNS'),
#  ("'", 'POS'),
#  ("'Search", 'NNP'),
#  ("'", 'POS'),
#  ("'Search", 'NNP'),
#  ("'", 'POS'),
#  ("'Appearance", 'NN'),
#  ("'Donate", 'NNP'),
#  ("'", 'POS'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
#  ("'", 'POS'),
#  ("'Log", 'NNP'),
#  ("'", 'POS'),
#  ("'Personal", 'NNP'),
#  ("'", 'POS'),
#  ("'tools", 'NNS'),
#  ("'", 'POS'),
#  ("'Donate", 'NNP'),
#  ("'", 'POS'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
#  ("'", 'POS'),
#  ("'Log", 'NNP'),
#  ("'", 'POS'),
#  ("'Pages", 'NNS'),
#  ("'", 'POS'),
#  ("'logged", 'VBD'),
#  ("'editors", 'NNS'),
#  ("'", 'POS'),
#  ("'learn", 'NNP'),
#  ("'", 'POS'),
#  ("'Contents", 'NNS'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Films", 'NNP'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Films", 'NNS'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Animated", 'VBD'),
#  ("'films", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Live", 'CD'),
#  ("'action", 'NNP'),
#  ("'", 'POS'),
#  ("'films", 'NNS'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Through", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glass", 'NNP'),
#  ("'", 'POS'),
#  ("'TV", 'NNP'),
#  ("'", 'POS'),
#  ("'series", 'NNS'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'TV", 'NNP'),
#  ("'", 'POS'),
#  ("'series", 'NNS'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Once", 'NN'),
#  ("'Time", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Bakery", 'NNP'),
#  ("'", 'POS'),
#  ("'Video", 'NNP'),
#  ("'", 'POS'),
#  ("'games", 'NNS'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Video", 'NNP'),
#  ("'", 'POS'),
#  ("'games", 'NNS'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Kingdom", 'NNP'),
#  ("'", 'POS'),
#  ("'Hearts", 'NNS'),
#  ("'", 'POS'),
#  ("'series", 'NNS'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Disney", 'NNP'),
#  ("'", 'POS'),
#  ("'Infinity", 'NNP'),
#  ("'", 'POS'),
#  ("'series", 'NNS'),
#  ("'", 'POS'),
#  ("'Disney", 'NNP'),
#  ("'", 'POS'),
#  ("'Magic", 'NNP'),
#  ("'", 'POS'),
#  ("'Kingdoms", 'NNS'),
#  ("'", 'POS'),
#  ("'park", 'NNP'),
#  ("'", 'POS'),
#  ("'attractions", 'NNS'),
#  ("'", 'POS'),
#  ("'rides", 'NNS'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'park", 'NNP'),
#  ("'", 'POS'),
#  ("'attractions", 'NNS'),
#  ("'", 'POS'),
#  ("'rides", 'NNS'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Maze", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Curious", 'JJ'),
#  ("'Labyrinth", 'NNP'),
#  ("'", 'POS'),
#  ("'Mad", 'NNP'),
#  ("'", 'POS'),
#  ("'Tea", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'ride", 'NNP'),
#  ("'", 'POS'),
#  ("'Mad", 'NNP'),
#  ("'", 'POS'),
#  ("'T", 'NNP'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'Stage", 'NN'),
#  ("'version", 'NNP'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Stage", 'NN'),
#  ("'version", 'NNP'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Jr", 'NNP'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'subsection", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Almost", 'FW'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'References", 'NNS'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'table", 'JJ'),
#  ("'contents", 'NNS'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'languages", 'NNS'),
#  ("'", 'POS'),
#  ("'Espa", 'NNP'),
#  ("'", 'POS'),
#  ("'ol", 'NNP'),
#  ("'", 'POS'),
#  ("'Edit", 'NNP'),
#  ("'", 'POS'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'ReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'Tools", 'NNS'),
#  ("'", 'POS'),
#  ("'Tools", 'NNS'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Actions", 'NNS'),
#  ("'", 'POS'),
#  ("'ReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'General", 'NNP'),
#  ("'", 'POS'),
#  ("'What", 'WP'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'hereRelated", 'VBD'),
#  ("'filePermanent", 'NNP'),
#  ("'", 'POS'),
#  ("'linkPage", 'NN'),
#  ("'informationCite", 'NNP'),
#  ("'", 'POS'),
#  ("'shortened", 'VBD'),
#  ("'QR", 'NNP'),
#  ("'", 'POS'),
#  ("'code", 'NNP'),
#  ("'", 'POS'),
#  ("'Print", 'NNP'),
#  ("'", 'POS'),
#  ("'export", 'NNP'),
#  ("'", 'POS'),
#  ("'PDFPrintable", 'JJ'),
#  ("'version", 'NNP'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'projects", 'NNS'),
#  ("'", 'POS'),
#  ("'Wikidata", 'NNP'),
#  ("'", 'POS'),
#  ("'item", 'NNP'),
#  ("'", 'POS'),
#  ("'Appearance", 'NN'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'From", 'IN'),
#  ("'Wikipedia", 'NNP'),
#  ("'", 'POS'),
#  ("'encyclopedia", 'NNP'),
#  ("'", 'POS'),
#  ("'Disney", 'NNP'),
#  ("'", 'POS'),
#  ("'media", 'NNP'),
#  ("'", 'POS'),
#  ("'based", 'VBD'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'books", 'NNS'),
#  ("'", 'POS'),
#  ("'Lewis", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'Portrayals", 'NNS'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Disney", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'WonderlandAbove", 'NNP'),
#  ("'", 'POS'),
#  ('A', 'NNP'),
#  ("'", 'POS'),
#  ("'logo", 'NNP'),
#  ("'", 'POS'),
#  ("'used", 'VBD'),
#  ("'represent", 'NNP'),
#  ("'", 'POS'),
#  ("'animated", 'VBD'),
#  ("'filmBelow", 'NNP'),
#  ("'", 'POS'),
#  ("'Logo", 'NNP'),
#  ("'", 'POS'),
#  ("'used", 'VBD'),
#  ("'live", 'CD'),
#  ("'action", 'NNP'),
#  ("'", 'POS'),
#  ("'filmCreated", 'VBD'),
#  ("'byWalt", 'NNP'),
#  ("'", 'POS'),
#  ("'DisneyOriginal", 'NNP'),
#  ("'", 'POS'),
#  ("'workAlice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'OwnerThe", 'NNP'),
#  ("'", 'POS'),
#  ("'Walt", 'NNP'),
#  ("'", 'POS'),
#  ("'Disney", 'NNP'),
#  ("'", 'POS'),
#  ("'CompanyYears", 'NNS'),
#  ("'", 'POS'),
#  ("'Based", 'VBD'),
#  ("'onAlice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Through", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glassby", 'NNP'),
#  ("'", 'POS'),
#  ("'Lewis", 'NNP'),
#  ("'", 'POS'),
#  ("'CarrollFilms", 'NNS'),
#  ("'", 'POS'),
#  ("'televisionFilm", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'animated", 'VBD'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'live", 'CD'),
#  ("'action", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Through", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glass", 'NNP'),
#  ("'", 'POS'),
#  ("'Television", 'NN'),
#  ("'series", 'NNS'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Once", 'NN'),
#  ("'Time", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Bakery", 'NNP'),
#  ("'", 'POS'),
#  ("'Theatrical", 'JJ'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Jr", 'NNP'),
#  ("'", 'POS'),
#  ("'GamesVideo", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Disney", 'NNP'),
#  ("'", 'POS'),
#  ("'Infinity", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'An", 'NNP'),
#  ("'", 'POS'),
#  ("'Original", 'NNP'),
#  ("'", 'POS'),
#  ("'Walt", 'NNP'),
#  ("'", 'POS'),
#  ("'Disney", 'NNP'),
#  ("'", 'POS'),
#  ("'Records", 'NNS'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Through", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glass", 'NNP'),
#  ("'", 'POS'),
#  ("'Original", 'NNP'),
#  ("'", 'POS'),
#  ("'Motion", 'NN'),
#  ("'Picture", 'NN'),
#  ("'Original", 'NNP'),
#  ("'", 'POS'),
#  ("'musicAlmost", 'FW'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'park", 'NNP'),
#  ("'", 'POS'),
#  ("'attraction", 'NN'),
#  ("'Mad", 'NNP'),
#  ("'", 'POS'),
#  ("'Tea", 'NNP'),
#  ("'", 'POS'),
#  ("'present", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'present", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Curious", 'JJ'),
#  ("'Labyrinth", 'NNP'),
#  ("'", 'POS'),
#  ("'present", 'NNP'),
#  ("'", 'POS'),
#  ("'Mad", 'NNP'),
#  ("'", 'POS'),
#  ("'T", 'NNP'),
#  ("'", 'POS'),
#  ("'Work", 'NNP'),
#  ("'", 'POS'),
#  ("'characters", 'NNS'),
#  ("'", 'POS'),
#  ("'settings", 'NNS'),
#  ("'", 'POS'),
#  ("'appeared", 'VBD'),
#  ("'part", 'NNP'),
#  ("'", 'POS'),
#  ("'Spin", 'NNP'),
#  ("'", 'POS'),
#  ("'off", 'NNP'),
#  ("'", 'POS'),
#  ("'TV", 'NNP'),
#  ("'", 'POS'),
#  ("'series", 'NNS'),
#  ("'", 'POS'),
#  ("'Once", 'NN'),
#  ("'Time", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'simply", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Disney", 'NNP'),
#  ("'", 'POS'),
#  ("'media", 'NNP'),
#  ("'", 'POS'),
#  ("'commencing", 'VBG'),
#  ("'theatrical", 'JJ'),
#  ("'release", 'NNP'),
#  ("'", 'POS'),
#  ("'animated", 'VBD'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'adaptation", 'NN'),
#  ("'books", 'NNS'),
#  ("'", 'POS'),
#  ("'Lewis", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'novel", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'sequel", 'NNP'),
#  ("'", 'POS'),
#  ("'Through", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glass", 'NNP'),
#  ("'", 'POS'),
#  ("'featured", 'VBD'),
#  ("'character", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ('A', 'NNP'),
#  ("'", 'POS'),
#  ("'live", 'CD'),
#  ("'action", 'NNP'),
#  ("'", 'POS'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'directed", 'VBD'),
#  ("'Tim", 'NNP'),
#  ("'", 'POS'),
#  ("'Burton", 'NNP'),
#  ("'", 'POS'),
#  ("'released", 'VBD'),
#  ("'Films", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'Film", 'NNP'),
#  ("'", 'POS'),
#  ('U', 'NNP'),
#  ("'", 'POS'),
#  ("'S", 'VBZ'),
#  ("'release", 'NNP'),
#  ("'", 'POS'),
#  ("'date", 'NNP'),
#  ("'", 'POS'),
#  ("'Director", 'NNP'),
#  ("'", 'POS'),
#  ("'Screenwriter", 'NNP'),
#  ("'", 'POS'),
#  ("'Story", 'NNP'),
#  ("'", 'POS'),
#  ("'Producer", 'NNP'),
#  ("'", 'POS'),
#  ("'Animated", 'VBD'),
#  ("'films", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'September", 'NNP'),
#  ("'", 'POS'),
#  ("'Clyde", 'NNP'),
#  ("'", 'POS'),
#  ("'Geronimi", 'NNP'),
#  ("'", 'POS'),
#  ("'Wilfred", 'VBD'),
#  ("'Jackson", 'NNP'),
#  ("'", 'POS'),
#  ("'Hamilton", 'NNP'),
#  ("'", 'POS'),
#  ("'Luske", 'NNP'),
#  ("'", 'POS'),
#  ("'Winston", 'NNP'),
#  ("'", 'POS'),
#  ("'Hibler", 'NNP'),
#  ("'", 'POS'),
#  ("'Ted", 'NNP'),
#  ("'", 'POS'),
#  ("'Sears", 'NNS'),
#  ("'", 'POS'),
#  ("'Bill", 'NNP'),
#  ("'", 'POS'),
#  ("'Peet", 'NNP'),
#  ("'", 'POS'),
#  ("'Erdman", 'NNP'),
#  ("'", 'POS'),
#  ("'Penner", 'NNP'),
#  ("'", 'POS'),
#  ("'Joe", 'NNP'),
#  ("'", 'POS'),
#  ("'Rinaldi", 'NNP'),
#  ("'", 'POS'),
#  ("'Banta", 'NNP'),
#  ("'", 'POS'),
#  ("'Bill", 'NNP'),
#  ("'", 'POS'),
#  ("'Cottrell", 'NNP'),
#  ("'", 'POS'),
#  ("'Dick", 'NNP'),
#  ("'", 'POS'),
#  ("'Kelsey", 'NNP'),
#  ("'", 'POS'),
#  ("'Joe", 'NNP'),
#  ("'", 'POS'),
#  ("'Grant", 'NNP'),
#  ("'", 'POS'),
#  ("'Dick", 'NNP'),
#  ("'", 'POS'),
#  ("'Del", 'NNP'),
#  ("'", 'POS'),
#  ("'Connell", 'NNP'),
#  ("'", 'POS'),
#  ("'Tom", 'NNP'),
#  ("'", 'POS'),
#  ("'Oreb", 'NNP'),
#  ("'", 'POS'),
#  ("'John", 'NNP'),
#  ("'", 'POS'),
#  ("'Walbridge", 'NNP'),
#  ("'", 'POS'),
#  ("'Walt", 'NNP'),
#  ("'", 'POS'),
#  ("'Disney", 'NNP'),
#  ("'", 'POS'),
#  ("'Ben", 'NNP'),
#  ("'", 'POS'),
#  ("'Live", 'CD'),
#  ("'action", 'NNP'),
#  ("'", 'POS'),
#  ("'films", 'NNS'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'March", 'NNP'),
#  ("'", 'POS'),
#  ("'Tim", 'NNP'),
#  ("'", 'POS'),
#  ("'Burton", 'NNP'),
#  ("'", 'POS'),
#  ("'Linda", 'NNP'),
#  ("'", 'POS'),
#  ("'Woolverton", 'NNP'),
#  ("'", 'POS'),
#  ("'Richard", 'NNP'),
#  ("'", 'POS'),
#  ("'D", 'NNP'),
#  ("'", 'POS'),
#  ("'Zanuck", 'NNP'),
#  ("'", 'POS'),
#  ("'Joe", 'NNP'),
#  ("'", 'POS'),
#  ("'Roth", 'NNP'),
#  ("'", 'POS'),
#  ("'Suzanne", 'NNP'),
#  ("'", 'POS'),
#  ("'Todd", 'NNP'),
#  ("'", 'POS'),
#  ("'Todd", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Through", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glass", 'NNP'),
#  ("'", 'POS'),
#  ("'May", 'NNP'),
#  ("'", 'POS'),
#  ("'James", 'NNS'),
#  ("'", 'POS'),
#  ("'Bobin", 'NNP'),
#  ("'", 'POS'),
#  ("'Joe", 'NNP'),
#  ("'", 'POS'),
#  ("'Roth", 'NNP'),
#  ("'", 'POS'),
#  ("'Suzanne", 'NNP'),
#  ("'", 'POS'),
#  ("'Todd", 'NNP'),
#  ("'", 'POS'),
#  ("'Todd", 'NNP'),
#  ("'", 'POS'),
#  ("'Tim", 'NNP'),
#  ("'", 'POS'),
#  ("'Burton", 'NNP'),
#  ("'", 'POS'),
#  ("'Animated", 'VBD'),
#  ("'films", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'American", 'JJ'),
#  ("'animated", 'VBD'),
#  ("'fantasy", 'NNP'),
#  ("'", 'POS'),
#  ("'comedy", 'NNP'),
#  ("'", 'POS'),
#  ("'adventure", 'NN'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'produced", 'VBD'),
#  ("'Walt", 'NNP'),
#  ("'", 'POS'),
#  ("'Disney", 'NNP'),
#  ("'", 'POS'),
#  ("'Productions", 'NNS'),
#  ("'", 'POS'),
#  ("'based", 'VBD'),
#  ("'primarily", 'RB'),
#  ("'", 'POS'),
#  ("'Lewis", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'several", 'NNP'),
#  ("'", 'POS'),
#  ("'additional", 'NNP'),
#  ("'", 'POS'),
#  ("'elements", 'NNS'),
#  ("'", 'POS'),
#  ("'sequel", 'NNP'),
#  ("'", 'POS'),
#  ("'Through", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glass", 'NNP'),
#  ("'", 'POS'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'released", 'VBD'),
#  ("'New", 'NNP'),
#  ("'", 'POS'),
#  ("'York", 'NNP'),
#  ("'", 'POS'),
#  ("'City", 'NNP'),
#  ("'", 'POS'),
#  ("'London", 'NNP'),
#  ("'", 'POS'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'features", 'NNS'),
#  ("'", 'POS'),
#  ("'voices", 'NNS'),
#  ("'", 'POS'),
#  ("'Kathryn", 'NNP'),
#  ("'", 'POS'),
#  ("'Beaumont", 'NNP'),
#  ("'", 'POS'),
#  ("'later", 'NNP'),
#  ("'", 'POS'),
#  ("'voiced", 'VBD'),
#  ("'Wendy", 'NNP'),
#  ("'", 'POS'),
#  ("'Darling", 'VBG'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'Peter", 'NNP'),
#  ("'", 'POS'),
#  ("'Pan", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Ed", 'NNP'),
#  ("'", 'POS'),
#  ("'Wynn", 'NNP'),
#  ("'", 'POS'),
#  ("'Mad", 'NNP'),
#  ("'", 'POS'),
#  ("'Hatter", 'NNP'),
#  ("'", 'POS'),
#  ("'song", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'since", 'NN'),
#  ("'become", 'NNP'),
#  ("'", 'POS'),
#  ("'jazz", 'NNP'),
#  ("'", 'POS'),
#  ("'standard", 'NNP'),
#  ("'", 'POS'),
#  ("'Live", 'CD'),
#  ("'action", 'NNP'),
#  ("'", 'POS'),
#  ("'films", 'NNS'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'American", 'JJ'),
#  ("'fantasy", 'NNP'),
#  ("'", 'POS'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'directed", 'VBD'),
#  ("'Tim", 'NNP'),
#  ("'", 'POS'),
#  ("'Burton", 'NNP'),
#  ("'", 'POS'),
#  ("'Linda", 'NNP'),
#  ("'", 'POS'),
#  ("'Woolverton", 'NNP'),
#  ("'", 'POS'),
#  ("'Released", 'VBD'),
#  ("'Walt", 'NNP'),
#  ("'", 'POS'),
#  ("'Disney", 'NNP'),
#  ("'", 'POS'),
#  ("'Pictures", 'NNS'),
#  ("'", 'POS'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'stars", 'NNS'),
#  ("'", 'POS'),
#  ("'Mia", 'NNP'),
#  ("'", 'POS'),
#  ("'Wasikowska", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Kingsleigh", 'NNP'),
#  ("'", 'POS'),
#  ("'Johnny", 'NNP'),
#  ("'", 'POS'),
#  ("'Depp", 'NNP'),
#  ("'", 'POS'),
#  ("'Anne", 'NNP'),
#  ("'", 'POS'),
#  ("'Hathaway", 'NNP'),
#  ("'", 'POS'),
#  ("'Helena", 'NNP'),
#  ("'", 'POS'),
#  ("'Bonham", 'NNP'),
#  ("'", 'POS'),
#  ("'Carter", 'NNP'),
#  ("'", 'POS'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'shot", 'NNP'),
#  ("'", 'POS'),
#  ("'United", 'VBD'),
#  ("'Kingdom", 'NNP'),
#  ("'", 'POS'),
#  ("'United", 'VBD'),
#  ("'States", 'VBZ'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Through", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glass", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Through", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glass", 'NNP'),
#  ("'", 'POS'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Through", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glass", 'NNP'),
#  ("'", 'POS'),
#  ("'American", 'JJ'),
#  ("'fantasy", 'NNP'),
#  ("'", 'POS'),
#  ("'film", 'NNP'),
#  ("'", 'POS'),
#  ("'directed", 'VBD'),
#  ("'James", 'NNS'),
#  ("'", 'POS'),
#  ("'Bobin", 'NNP'),
#  ("'", 'POS'),
#  ("'Linda", 'NNP'),
#  ("'", 'POS'),
#  ...]

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = [ 'Words', "Word type"]
df_t=df_text.groupby('Word type').count().reset_index()
top20=df_t.nlargest(20, 'Words')

# %% [markdown]
# ## Creating Bar Plots

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 20):
      sns.barplot(x = "Words", y = "Word type",
     saturation = 0.9, data = top20).set_title("Alice's Adventures in Wonderland - top 20 word types used")

# %%
df = df_text[(df_text['Word type'] == "NN") | (df_text['Word type'] == "NNS") | (df_text['Word type'] == "NNS")]
df.columns = ["Word", "Occurrences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurrences'], ascending=False)
top10 = y.nlargest(10, 'Occurrences')

# %%
plt.figure(figsize=(10, 5))

# Set a better color palette
sns.set_palette("Blues_d")  # A darker shade of blue

# Create the bar plot
sns.barplot(x="Word", y="Occurrences", saturation=0.9, data=top10).set_title("Alice's Adventures in Wonderland - Most Frequently Used Nouns")

plt.show()

# %% [markdown]
# ## Bar Plots for Text Mining Specific Information

# %%
listToStr = ' '.join([str(elem) for elem in filtered])

print(listToStr)
# Out:
# Alice Wonderland franchise Wikipedia Jump content Main menu Main menu move sidebar hide Navigation Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us Contribute HelpLearn editCommunity portalRecent changesUpload fileSpecial pages Search Search Appearance Donate Create account Log Personal tools Donate Create account Log Pages logged editors learn ContributionsTalk Contents move sidebar hide Top Films Toggle Films subsection Animated films Alice Wonderland Live action films Alice Wonderland Alice Through Looking Glass TV series Toggle TV series subsection Adventures Wonderland Once Upon Time Wonderland Alice Wonderland Bakery Video games Toggle Video games subsection Alice Wonderland Kingdom Hearts series Alice Wonderland Disney Infinity series Disney Magic Kingdoms Theme park attractions rides Toggle Theme park attractions rides subsection Alice Wonderland Maze Alice Curious Labyrinth Mad Tea Party Alice Wonderland ride Mad T Party It Small World Stage version Toggle Stage version subsection Alice Wonderland Jr Music Toggle Music subsection Alice Wonderland soundtrack Almost Alice References Toggle table contents Alice Wonderland franchise languages Espa ol Edit links ArticleTalk English ReadEditView history Tools Tools move sidebar hide Actions ReadEditView history General What links hereRelated changesUpload filePermanent linkPage informationCite pageGet shortened URLDownload QR code Print export Download PDFPrintable version In projects Wikidata item Appearance move sidebar hide From Wikipedia free encyclopedia Disney media franchise based Alice books Lewis Carroll See also Portrayals Alice Wonderland Disney Alice WonderlandAbove A logo used represent animated filmBelow Logo used live action filmCreated byWalt DisneyOriginal workAlice Wonderland OwnerThe Walt Disney CompanyYears Based onAlice Adventures Wonderland Through Looking Glassby Lewis CarrollFilms televisionFilm Alice Wonderland animated Alice Wonderland live action Alice Through Looking Glass Television series Adventures Wonderland Once Upon Time Wonderland Alice Wonderland Bakery Theatrical presentationsPlay Alice Wonderland Jr GamesVideo game Alice Wonderland Alice Wonderland Disney Infinity AudioSoundtrack Alice Wonderland Alice Wonderland An Original Walt Disney Records Soundtrack Alice Through Looking Glass Original Motion Picture Soundtrack Original musicAlmost Alice MiscellaneousTheme park attraction Mad Tea Party present Alice Wonderland present Alice Curious Labyrinth present Mad T Party Work franchise characters settings appeared part crossover Spin off TV series Once Upon Time Alice Wonderland simply Alice Disney media franchise commencing theatrical release animated film Alice Wonderland film adaptation books Lewis Carroll novel Alice Adventures Wonderland sequel Through Looking Glass featured character Alice A live action film directed Tim Burton released Films edit Film U S release date Director Screenwriter Story Producer Animated films Alice Wonderland September Clyde Geronimi Wilfred Jackson Hamilton Luske Winston Hibler Ted Sears Bill Peet Erdman Penner Joe Rinaldi Milt Banta Bill Cottrell Dick Kelsey Joe Grant Dick Huemer Del Connell Tom Oreb John Walbridge Walt Disney Ben Sharpsteen Live action films Alice Wonderland March Tim Burton Linda Woolverton Richard D Zanuck Joe Roth Suzanne Todd Jennifer Todd Alice Through Looking Glass May James Bobin Joe Roth Suzanne Todd Jennifer Todd Tim Burton Animated films edit Alice Wonderland edit Main article Alice Wonderland film Alice Wonderland American animated fantasy comedy adventure film produced Walt Disney Productions based primarily Lewis Carroll Alice Adventures Wonderland several additional elements sequel Through Looking Glass film released New York City London July features voices Kathryn Beaumont later voiced Wendy Darling film Peter Pan Alice Ed Wynn Mad Hatter theme song Alice Wonderland since become jazz standard Live action films edit Alice Wonderland edit Main article  ...

# %%
# Create a count for the main characters

all_counts = Counter(re.sub(r'\W+', ' ', listToStr).split())

# %%
# Replace names with aliases
chars = pd.DataFrame({
    'character': [
        'Alice', 'Bill the Lizard', 'The Queen of Hearts', 
        'The King of Hearts', 'The Knave of Hearts'
    ]
})

chars['character'] = chars['character'].replace('Bill the Lizard','Bill')
chars['character'] = chars['character'].replace('The Queen of Hearts','Queen')
chars['character'] = chars['character'].replace('The King of Hearts','King')
chars['character'] = chars['character'].replace('The Knave of Hearts','Knave')

# %%
chars['character_alias'] = chars['character'].apply(lambda x: x.rsplit(' ',1)[-1])

# %%
chars
# Out:
#   character character_alias
# 0     Alice           Alice
# 1      Bill            Bill
# 2     Queen           Queen
# 3      King            King
# 4     Knave           Knave

# %%
chars_list = chars['character_alias'].to_list()

# %%
dict_of_counts = {d : all_counts[d] for d in chars_list}

# %%
#Search for the names from the list in the dictionary

dct = {v:[k] for v,k in dict_of_counts.items()}
df = pd.DataFrame(dct)

# %%
df
# Out:
#    Alice  Bill  Queen  King  Knave
# 0    169     5      5     5      1

# %%
data = {'Alice': [169], 'Bill': [5], 'Queen': [5], 'King': [5], 'Knave': [1]}
df = pd.DataFrame(data)

# Reshape the dataframe
df = df.melt(var_name='CHARACTER', value_name='TIMES MENTIONED')

# Show the final table
print(df)
# Out:
#   CHARACTER  TIMES MENTIONED
# 0     Alice              169
# 1      Bill                5
# 2     Queen                5
# 3      King                5
# 4     Knave                1

# %%
df = pd.DataFrame({
    'CHARACTER': ['Alice', 'Bill', 'Queen', 'King', 'Knave'],
    'TIMES MENTIONED': [169, 5, 5, 5, 1]
})

# Plotting the bar chart
plt.figure(figsize=(8, 6))
plt.bar(df['CHARACTER'], df['TIMES MENTIONED'], color='skyblue')

# Labels and title
plt.title('Character Mentions')
plt.xlabel('CHARACTER')
plt.ylabel('TIMES MENTIONED')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Sentiment Analysis

# %%
text_sent = TextBlob(str(filtered))
print(text_sent.sentiment)
# Out:
# Sentiment(polarity=-0.00954657842157842, subjectivity=0.44576348651348674)
