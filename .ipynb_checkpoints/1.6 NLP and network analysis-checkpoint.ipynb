# %% [markdown]
# # Import libraries

# %%
import pandas as pd 
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
NER = spacy.load("en_core_web_sm")

# %% [markdown]
# # Creating an NER Object

# %%
# Load the book

with open('alice_article_wiki.txt', 'r', errors='ignore') as file: 
   data = file.read().replace( '\n', ' ')

book = NER(data)

# %%
# Visualize identified entities

displacy.render(book[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">References                   Toggle the table of contents        Alice in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (franchise)
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  languages
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     БългарскиEspañol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#   Edit links            ArticleTalk
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
#                   ReadEditView history
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tools      Tools
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  move to sidebar hide    		Actions 	   ReadEditView history      		General 	   What links hereRelated changesUpload filePermanent linkPage informationCite this pageGet shortened
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     URLDownload
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  QR code      		Print/export
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Download
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PDFPrintable
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  version      		In other projects
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikidata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  item                      Appearance move to sidebar hide           From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikipedia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the free encyclopedia
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Disney
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  media franchise based on the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  books by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lewis Carroll See
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  also: Portrayals of Alice in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  §
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Disney Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WonderlandAbove
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : A logo used to represent the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1951
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  animated filmBelow: Logo used for the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  live-action filmCreated byWalt
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DisneyOriginal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  workAlice in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1951)OwnerThe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Walt Disney CompanyYears1951
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -2024Based onAlice's Adventures in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and Through the Looking-Glassby Lewis CarrollFilms and
# <mark class="entity" style="background: #

# %% [markdown]
# ## Splitting Sentence Entities

# %%
df_sentences = []

# Loop through sentences, get entity list for each sentence
for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})

df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (    , Alice, in, Wonderland, (, franchise, ),...
# 1  (1, Films,     , Toggle, Films, subsection,   ...
# 2    (Once, Upon, a, Time, in, Wonderland,         )
# 3  (2.3, Alice, 's, Wonderland, Bakery,          ...
# 4  (informationCite, this, pageGet, shortened, UR...
# 5  (A, logo, used, to, represent, the, 1951, anim...
# 6  (Television, series, Adventures, in, Wonderlan...
# 7  (Once, Upon, a, Time, in, Wonderland, (, 2013–...
# 8                (Alice, in, Wonderland, (, 2010, ))
# 9  (Disney, Infinity, 3.0, (, 2015, ), *, AudioSo...
#
#                                             entities
# 0  [Wonderland, Search            Search         ...
# 1  [1, 1.1.1, Alice in Wonderland           , 1.2...
# 2                                       [Wonderland]
# 3  [2.3, Alice, 3, Toggle Video, 3.1, Wonderland,...
# 4  [URLDownload, Download, PDFPrintable, Wikidata...
# 5  [1951, 2010, DisneyOriginal, Wonderland, 1951)...
# 6                            [Wonderland, 1992–1995]
# 7  [Wonderland, Alice, 2022–2024, Wonderland, Ali...
# 8                          [Alice, Wonderland, 2010]
# 9  [Disney Infinity, 2015, Alice, Wonderland, 195...

# %% [markdown]
# ## Filtering Data Using the Main Characters

# %%
# import the characters data set as a pandas dataframe
character_df=pd.read_csv('/Users/yasersouri/Desktop/data analysis/specialization 1/Alice_Network_Analysis/character_df.csv',index_col=0)

# %%
# keep only the last part of the strings in chars using an rsplit() function:
character_df['character_alias'] = character_df['character'].apply(lambda x: x.rsplit(' ',1)[-1])
character_df.head(5)
# Out:
#           character character_alias
# 0             Alice           Alice
# 1  The White Rabbit          Rabbit
# 2         The Mouse           Mouse
# 3          The Dodo            Dodo
# 4          The Lory            Lory

# %%
# Function to filter out entities not of interest
def filter_entity(ent_list, character_df):
    return [ent for ent in ent_list if ent in list(character_df['character_alias'])]

# %%
# pass the sentence entities and the characters dataframe into a filter, which will return only the entities of interest:
df_sentences['character_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, character_df))

# %%
# Filter out sentences that don’t have any character entities

df_sentences_filtered = df_sentences[df_sentences['character_entities'].map(len) > 0]

df_sentences_filtered.tail(10)
# Out:
#                                               sentence  \
# 119  (Alice, in, Wonderland, (, 1966, ), Alice, Thr...
# 122  (Alice, through, the, Looking, Glass, (, 1998, ))
# 123  (Alice, in, Wonderland, (, 1999, ), Alice, (, ...
# 124  (Once, Upon, a, Time, in, Wonderland, (, 2013,...
# 126                (Alice, in, Wonderland, (, 2010, ))
# 127  (Almost, Alice, (, 2010, ), ", Alice, ", ", Fo...
# 128  (", Just, Like, Fire, ", ", Alice, ", (, 2020,...
# 130  (Alice, no, Paint, Adventure, (, 1995, ), Alic...
# 156  (The, Adventures, of, Ichabod, and, Mr., Toad,...
# 192  (Walt, &, El, Grupo, (, 2009, ), Miscellaneous...
#
#                                               entities  \
# 119     [Alice, Wonderland, 1966, Alice Through, 1983]
# 122                   [Alice, the Looking Glass, 1998]
# 123             [Alice, Wonderland, 1999, Alice, 2009]
# 124  [Wonderland, 2013, Alice, 2022, Artwork Alice,...
# 126                          [Alice, Wonderland, 2010]
# 127  [Alice, 2010, Alice, Follow Me Down, Tea Party...
# 128  [Just Like Fire, Alice, 2020, the Looking Glas...
# 130  [Alice no Paint Adventure, 1995, Alice, Wonder...
# 156  [The Adventures of Ichabod, Toad, 1949, Cinder...
# 192  [Walt & El Grupo, 2009, Walt Disney Animation ...
#
#                character_entities
# 119                       [Alice]
# 122                       [Alice]
# 123                [Alice, Alice]
# 124                       [Alice]
# 126                       [Alice]
# 127                [Alice, Alice]
# 128                [Alice, Alice]
# 130  [Alice, Alice, Alice, Alice]
# 156                       [Alice]
# 192                       [Alice]

# %%
# Take only the first name of the characters

df_sentences_filtered['character_entities'] = df_sentences_filtered['character_entities'].apply(lambda x: [item.split()[0]
                                                                                                    for item in x])
# Out:
# /var/folders/cd/8vl1s70d6dqgshpmc74wr4hw0000gn/T/ipykernel_987/321061435.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sentences_filtered['character_entities'] = df_sentences_filtered['character_entities'].apply(lambda x: [item.split()[0]

# %%
df_sentences_filtered.tail(10)
# Out:
#                                               sentence  \
# 119  (Alice, in, Wonderland, (, 1966, ), Alice, Thr...
# 122  (Alice, through, the, Looking, Glass, (, 1998, ))
# 123  (Alice, in, Wonderland, (, 1999, ), Alice, (, ...
# 124  (Once, Upon, a, Time, in, Wonderland, (, 2013,...
# 126                (Alice, in, Wonderland, (, 2010, ))
# 127  (Almost, Alice, (, 2010, ), ", Alice, ", ", Fo...
# 128  (", Just, Like, Fire, ", ", Alice, ", (, 2020,...
# 130  (Alice, no, Paint, Adventure, (, 1995, ), Alic...
# 156  (The, Adventures, of, Ichabod, and, Mr., Toad,...
# 192  (Walt, &, El, Grupo, (, 2009, ), Miscellaneous...
#
#                                               entities  \
# 119     [Alice, Wonderland, 1966, Alice Through, 1983]
# 122                   [Alice, the Looking Glass, 1998]
# 123             [Alice, Wonderland, 1999, Alice, 2009]
# 124  [Wonderland, 2013, Alice, 2022, Artwork Alice,...
# 126                          [Alice, Wonderland, 2010]
# 127  [Alice, 2010, Alice, Follow Me Down, Tea Party...
# 128  [Just Like Fire, Alice, 2020, the Looking Glas...
# 130  [Alice no Paint Adventure, 1995, Alice, Wonder...
# 156  [The Adventures of Ichabod, Toad, 1949, Cinder...
# 192  [Walt & El Grupo, 2009, Walt Disney Animation ...
#
#                character_entities
# 119                       [Alice]
# 122                       [Alice]
# 123                [Alice, Alice]
# 124                       [Alice]
# 126                       [Alice]
# 127                [Alice, Alice]
# 128                [Alice, Alice]
# 130  [Alice, Alice, Alice, Alice]
# 156                       [Alice]
# 192                       [Alice]
